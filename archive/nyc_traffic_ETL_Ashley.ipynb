# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime

# %%
df = pd.read_csv('/content/drive/MyDrive/Colab/NYC-EMS-Response/data/ny_events (1).csv')

# %%
# remove data outside NYC 5 B's
nyc = ['Bronx', # Bronx
 'Bronx/New York',
 'Bronx/New York/Queens',
 'Bronx/Queens',
 'New York / Bronx',
'Kings', # Brooklyn
 'Kings County',
 'Kings/New York',
 'Kings/Queens',
 'Kings/Richmond',
 'Brooklyn',
 'New York/Kings',
 'kings',
'Manhattan', # Manhattan
 'New York',
 'New Yrok',
 'New york',
'Queens County', # Queens
 'Queens/Kings/Nassau/Suffok',
 'Queens/New York',
 'New York/Queens',
'Richmond'] # Stat Rats

df = df[df['County'].isin(nyc)]

# drop useless cols
df.drop(columns=[
        'Event Type',
        'Organization Name',
        'Facility Name',
        'Direction',
        'Event Description',
        'Responding Organization Id',
        'State',
        'City'
], inplace=True)

# convert columns to datetime
df['Create Time']= pd.to_datetime(df['Create Time'])
df['Close Time']= pd.to_datetime(df['Close Time'])

# extract day, month, year, hour
df['year']=df['Create Time'].apply(lambda x: x.year)
df['month']=df['Create Time'].apply(lambda x: x.month)
df['day']=df['Create Time'].apply(lambda x: x.day)
df['hour']=df['Create Time'].apply(lambda x: x.hour)

# %%
df.shape
# Out:
# (170290, 9)

# %%
df.head()
# Out:
#       County         Create Time          Close Time  ...  month  day  hour
# 0      Bronx 2016-02-14 06:05:00 2016-02-14 07:03:00  ...      2   14     6
# 3   New York 2016-02-14 06:21:00 2016-02-14 13:28:00  ...      2   14     6
# 13     Bronx 2016-02-14 06:42:00 2016-02-14 07:01:00  ...      2   14     6
# 14     Bronx 2016-02-14 18:43:00 2016-02-14 18:47:00  ...      2   14    18
# 15  New York 2016-02-14 06:44:00 2016-02-14 11:23:00  ...      2   14     6
#
# [5 rows x 9 columns]

# %%
#df['Create Time'] = df['Create Time'].dt.tz_localize(tz='EST')

# %%
#df['Create Time'] = df['Create Time'].dt.tz_convert(tz='UTC')

# %%
#df['Create Time'] = df['Create Time'].astype(str)

# %%
#new_time = [i[0:13] for i in df['Create Time']]

# %%
#new_time = [datetime.strptime(i, '%Y-%m-%d %H') for i in new_time]

# %%
#new_time = [i.timestamp() for i in new_time]

# %%
#new_time = [int(i) for i in new_time]

# %%
#df['UTC'] = new_time

# %%
new_county = []
for i in df['County']: 
  if i in ['Bronx','Bronx/New York','Bronx/New York/Queens','Bronx/Queens','New York / Bronx']:
    i = 'Bronx'
    new_county.append(i)
  elif i in ['Kings','Kings County','Kings/New York','Kings/Queens','Kings/Richmond','Brooklyn','New York/Kings','kings']:
    i = 'Brooklyn'
    new_county.append(i)
  elif i in ['Manhattan','New York','New Yrok','New york']:
    i = 'Manhattan'
    new_county.append(i)
  elif i in ['Queens County','Queens/Kings/Nassau/Suffok','Queens/New York','New York/Queens']:
    i = 'Queens'
    new_county.append(i)
  elif i in ['Richmond']:
    i = 'Richmond / Staten Island'
    new_county.append(i)
  else:
    print(i)

# %%
df['County'] = new_county

# %%
df.head()
# Out:
#        County         Create Time          Close Time  ...  month  day  hour
# 0       Bronx 2016-02-14 06:05:00 2016-02-14 07:03:00  ...      2   14     6
# 3   Manhattan 2016-02-14 06:21:00 2016-02-14 13:28:00  ...      2   14     6
# 13      Bronx 2016-02-14 06:42:00 2016-02-14 07:01:00  ...      2   14     6
# 14      Bronx 2016-02-14 18:43:00 2016-02-14 18:47:00  ...      2   14    18
# 15  Manhattan 2016-02-14 06:44:00 2016-02-14 11:23:00  ...      2   14     6
#
# [5 rows x 9 columns]

# %%
df['Create Time'].min()
# Out:
# Timestamp('2010-01-02 02:51:00')

# %%
df['Create Time'].max()
# Out:
# Timestamp('2020-01-01 01:01:00')

# %%
df[df['year'] == 2020]
# Out:
#            County         Create Time          Close Time  ...  month  day  hour
# 30867   Manhattan 2020-01-01 01:01:00 2020-01-01 01:16:00  ...      1    1     1
# 106370  Manhattan 2020-01-01 01:01:00 2020-01-01 01:16:00  ...      1    1     1
# 106598  Manhattan 2020-01-01 01:01:00 2020-01-01 01:16:00  ...      1    1     1
#
# [3 rows x 9 columns]

# %%
new_df = df.groupby(["County", "year", "month", "day", "hour"]).size().reset_index(name="Incidences")

# %%
new_df
# Out:
#                          County  year  month  day  hour  Incidences
# 0                         Bronx  2010      1    8     6           1
# 1                         Bronx  2010      1    9    10           3
# 2                         Bronx  2010      1    9    11           3
# 3                         Bronx  2010      1   10    12           2
# 4                         Bronx  2010      1   15     8           1
# ...                         ...   ...    ...  ...   ...         ...
# 63389  Richmond / Staten Island  2016      8   23    13           1
# 63390  Richmond / Staten Island  2016      8   23    14           7
# 63391  Richmond / Staten Island  2016      8   23    15           1
# 63392  Richmond / Staten Island  2016      8   23    18           1
# 63393  Richmond / Staten Island  2016      8   23    20           2
#
# [63394 rows x 6 columns]

# %%
new_df[new_df['year'] == 2020]
# Out:
#           County  year  month  day  hour  Incidences
# 55480  Manhattan  2020      1    1     1           3

# %%
data = pd.read_csv('/content/drive/MyDrive/Colab/NYC-EMS-Response/data/ems_weather_new.csv')

# %%
data
# Out:
#        Unnamed: 0  CAD_INCIDENT_ID  ...  TMIN  TAVG_CALC
# 0               0        110011884  ...  40.0       46.5
# 1               1        110013013  ...  40.0       46.5
# 2               2        110014121  ...  40.0       46.5
# 3               3        110015204  ...  40.0       46.5
# 4               4        110020794  ...  35.0       43.5
# ...           ...              ...  ...   ...        ...
# 20021       20021        210022518  ...  36.0       43.5
# 20022       20022        210023653  ...  36.0       43.5
# 20023       20023        210030693  ...  34.0       36.0
# 20024       20024        210031849  ...  34.0       36.0
# 20025       20025        210033031  ...  34.0       36.0
#
# [20026 rows x 856 columns]

# %%
data = data[(data['CALL_YEAR'] <= 2016)]

# %%
data = data[(data['CALL_YEAR'] >= 2010)]

# %%
data
# Out:
#        Unnamed: 0  CAD_INCIDENT_ID  ...  TMIN  TAVG_CALC
# 0               0        110011884  ...  40.0       46.5
# 1               1        110013013  ...  40.0       46.5
# 2               2        110014121  ...  40.0       46.5
# 3               3        110015204  ...  40.0       46.5
# 4               4        110020794  ...  35.0       43.5
# ...           ...              ...  ...   ...        ...
# 11145       11145        163653671  ...  33.0       36.5
# 11146       11146        163660457  ...  31.0       37.5
# 11147       11147        163661551  ...  31.0       37.5
# 11148       11148        163662645  ...  31.0       37.5
# 11149       11149        163663744  ...  31.0       37.5
#
# [8835 rows x 856 columns]

# %%
data.reset_index(inplace=True)

# %%
data
# Out:
#       index  Unnamed: 0  CAD_INCIDENT_ID  ...  TMAX  TMIN  TAVG_CALC
# 0         0           0        110011884  ...  53.0  40.0       46.5
# 1         1           1        110013013  ...  53.0  40.0       46.5
# 2         2           2        110014121  ...  53.0  40.0       46.5
# 3         3           3        110015204  ...  53.0  40.0       46.5
# 4         4           4        110020794  ...  52.0  35.0       43.5
# ...     ...         ...              ...  ...   ...   ...        ...
# 8830  11145       11145        163653671  ...  40.0  33.0       36.5
# 8831  11146       11146        163660457  ...  44.0  31.0       37.5
# 8832  11147       11147        163661551  ...  44.0  31.0       37.5
# 8833  11148       11148        163662645  ...  44.0  31.0       37.5
# 8834  11149       11149        163663744  ...  44.0  31.0       37.5
#
# [8835 rows x 857 columns]

# %%
data.drop(columns='Unnamed: 0', inplace=True)

# %%
data
# Out:
#       index  CAD_INCIDENT_ID  ...  TMIN  TAVG_CALC
# 0         0        110011884  ...  40.0       46.5
# 1         1        110013013  ...  40.0       46.5
# 2         2        110014121  ...  40.0       46.5
# 3         3        110015204  ...  40.0       46.5
# 4         4        110020794  ...  35.0       43.5
# ...     ...              ...  ...   ...        ...
# 8830  11145        163653671  ...  33.0       36.5
# 8831  11146        163660457  ...  31.0       37.5
# 8832  11147        163661551  ...  31.0       37.5
# 8833  11148        163662645  ...  31.0       37.5
# 8834  11149        163663744  ...  31.0       37.5
#
# [8835 rows x 856 columns]

# %%
data.shape
# Out:
# (8835, 856)

# %%
boro = []
for i in range(8835):
  if data['BOROUGH_BROOKLYN'][i] == 1:
    boro.append("Brooklyn")
  elif data['BOROUGH_MANHATTAN'][i] == 1:
    boro.append("Manhattan")
  elif data['BOROUGH_QUEENS'][i] == 1:
    boro.append("Queens")
  elif data['BOROUGH_RICHMOND / STATEN ISLAND'][i] == 1:
    boro.append("Richmond / Staten Island")
  else:
    boro.append("Bronx")

# %%
len(boro)
# Out:
# 8835

# %%
data['Borough'] = boro

# %%
data
# Out:
#       index  CAD_INCIDENT_ID  ...  TAVG_CALC   Borough
# 0         0        110011884  ...       46.5    Queens
# 1         1        110013013  ...       46.5     Bronx
# 2         2        110014121  ...       46.5    Queens
# 3         3        110015204  ...       46.5  Brooklyn
# 4         4        110020794  ...       43.5    Queens
# ...     ...              ...  ...        ...       ...
# 8830  11145        163653671  ...       36.5     Bronx
# 8831  11146        163660457  ...       37.5     Bronx
# 8832  11147        163661551  ...       37.5  Brooklyn
# 8833  11148        163662645  ...       37.5  Brooklyn
# 8834  11149        163663744  ...       37.5     Bronx
#
# [8835 rows x 857 columns]

# %%
data['Borough'].value_counts()
# Out:
# Brooklyn                    2555
# Manhattan                   2142
# Bronx                       2096
# Queens                      1708
# Richmond / Staten Island     334
# Name: Borough, dtype: int64

# %%
new_df['County'].value_counts()
# Out:
# Manhattan                   21237
# Brooklyn                    18135
# Bronx                       16109
# Richmond / Staten Island     6212
# Queens                       1701
# Name: County, dtype: int64

# %%
ems_weather_tfk = pd.merge(left=data, right=new_df,  how='inner', left_on=['Borough','CALL_YEAR','CALL_MONTH', 'CALL_DAY', 'CALL_HOUR'], right_on = ['County','year','month','day', 'hour'])

# %%
ems_weather_tfk
# Out:
#       index  CAD_INCIDENT_ID  ...  hour  Incidences
# 0        77        110241339  ...    10           1
# 1        84        110261612  ...    11           1
# 2       107        110340066  ...    12           1
# 3       108        110341185  ...    10           1
# 4       124        110591028  ...     9           1
# ...     ...              ...  ...   ...         ...
# 1847  10924        103071018  ...     9           1
# 1848  10969        103210246  ...     2           1
# 1849  10992        103280663  ...     7           1
# 1850  11007        103330127  ...     1           1
# 1851  11008        103331198  ...    10           1
#
# [1852 rows x 863 columns]

# %%
ems_weather_tfk.to_csv('/content/drive/MyDrive/Colab/NYC-EMS-Response/data/ems_weather_tfk.csv')
