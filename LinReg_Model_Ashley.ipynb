# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

from sklearn.model_selection import train_test_split, GridSearchCV
from sklearn.linear_model import LinearRegression, Lasso, Ridge, LassoCV, RidgeCV
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import mean_squared_error
from sklearn.pipeline import Pipeline

# %%
df = pd.read_csv('data/ems_weather.csv')

# %% [markdown]
# ## **Linear Regression Models**

# %%
df.head()
# Out:
#    Unnamed: 0  CAD_INCIDENT_ID  INITIAL_SEVERITY_LEVEL_CODE  \
# 0           0        110011884                            4
# 1           1        110013013                            6
# 2           2        110014121                            4
# 3           3        110015204                            2
# 4           4        110020794                            4
#
#    FINAL_SEVERITY_LEVEL_CODE  FIRST_ASSIGNMENT_DATETIME  \
# 0                          4                        9.0
# 1                          6                       28.0
# 2                          4                       10.0
# 3                          2                       16.0
# 4                          6                       27.0
#
#    VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                               1                             9
# 1                               1                            28
# 2                               1                            10
# 3                               1                            16
# 4                               1                            27
#
#    FIRST_ACTIVATION_DATETIME  VALID_INCIDENT_RSPNS_TIME_INDC  \
# 0                       16.0                               1
# 1                      127.0                               1
# 2                       19.0                               1
# 3                       44.0                               1
# 4                       46.0                               1
#
#    INCIDENT_RESPONSE_SECONDS_QY  ...  CALL_MONTH_OCT  CALL_MONTH_SEP  \
# 0                         480.0  ...               0               0
# 1                         674.0  ...               0               0
# 2                         399.0  ...               0               0
# 3                         272.0  ...               0               0
# 4                         920.0  ...               0               0
#
#    CALL_MONTH  AWND  PRCP  SNOW  SNWD  TMAX  TMIN  TAVG_CALC
# 0           1  3.13  0.00   0.0  12.0  53.0  40.0       46.5
# 1           1  3.13  0.00   0.0  12.0  53.0  40.0       46.5
# 2           1  3.13  0.00   0.0  12.0  53.0  40.0       46.5
# 3           1  3.13  0.00   0.0  12.0  53.0  40.0       46.5
# 4           1  5.14  0.01   0.0   9.0  52.0  35.0       43.5
#
# [5 rows x 855 columns]

# %% [markdown]
# #### Setting up y and X (incl removing dispatch time)

# %%
y = df['INCIDENT_RESPONSE_SECONDS_QY']

features = df.columns
# definitely drop these:
drop_features = ['Unnamed: 0',
                 'INCIDENT_RESPONSE_SECONDS_QY', 
                 'CAD_INCIDENT_ID', 
                 'FIRST_ASSIGNMENT_DATETIME', 
                 'DISPATCH_RESPONSE_SECONDS_QY',
]
# suggest dropping these: 
drop_features += list(features[230:594]) # zip codes
drop_features += list(features[670:831]) # city council district, community district, community school dist, congressional district
drop_features += ['AWND']

X = df.drop(columns=drop_features)

# %% [markdown]
# #### Setting up new X (removing travel time instead of dispatch time)

# %%
# definitely drop these:
drop_features1 = ['Unnamed: 0',
                 'INCIDENT_RESPONSE_SECONDS_QY', 
                 'CAD_INCIDENT_ID', 
                 'FIRST_ASSIGNMENT_DATETIME', 
                 'INCIDENT_TRAVEL_TM_SECONDS_QY']
# suggest dropping these: 
drop_features1 += list(features[230:594]) # zip codes
drop_features1 += list(features[670:831]) # city council district, community district, community school dist, congressional district
drop_features1 += ['AWND']

X1 = df.drop(columns=drop_features1)

# %%
X.head()
# Out:
#    INITIAL_SEVERITY_LEVEL_CODE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            4                          4
# 1                            6                          6
# 2                            4                          4
# 3                            2                          2
# 4                            4                          6
#
#    VALID_DISPATCH_RSPNS_TIME_INDC  FIRST_ACTIVATION_DATETIME  \
# 0                               1                       16.0
# 1                               1                      127.0
# 2                               1                       19.0
# 3                               1                       44.0
# 4                               1                       46.0
#
#    VALID_INCIDENT_RSPNS_TIME_INDC  INCIDENT_TRAVEL_TM_SECONDS_QY  \
# 0                               1                          471.0
# 1                               1                          646.0
# 2                               1                          389.0
# 3                               1                          256.0
# 4                               1                          893.0
#
#    INCIDENT_CLOSE_DATETIME  HELD_INDICATOR  REOPEN_INDICATOR  \
# 0                   1583.0               0                 0
# 1                  48712.0               0                 0
# 2                   2654.0               0                 0
# 3                    591.0               0                 0
# 4                   5868.0               0                 0
#
#    SPECIAL_EVENT_INDICATOR  ...  CALL_MONTH_NOV  CALL_MONTH_OCT  \
# 0                        0  ...               0               0
# 1                        0  ...               0               0
# 2                        0  ...               0               0
# 3                        0  ...               0               0
# 4                        0  ...               0               0
#
#    CALL_MONTH_SEP  CALL_MONTH  PRCP  SNOW  SNWD  TMAX  TMIN  TAVG_CALC
# 0               0           1  0.00   0.0  12.0  53.0  40.0       46.5
# 1               0           1  0.00   0.0  12.0  53.0  40.0       46.5
# 2               0           1  0.00   0.0  12.0  53.0  40.0       46.5
# 3               0           1  0.00   0.0  12.0  53.0  40.0       46.5
# 4               0           1  0.01   0.0   9.0  52.0  35.0       43.5
#
# [5 rows x 324 columns]

# %%
X1.head()
# Out:
#    INITIAL_SEVERITY_LEVEL_CODE  FINAL_SEVERITY_LEVEL_CODE  \
# 0                            4                          4
# 1                            6                          6
# 2                            4                          4
# 3                            2                          2
# 4                            4                          6
#
#    VALID_DISPATCH_RSPNS_TIME_INDC  DISPATCH_RESPONSE_SECONDS_QY  \
# 0                               1                             9
# 1                               1                            28
# 2                               1                            10
# 3                               1                            16
# 4                               1                            27
#
#    FIRST_ACTIVATION_DATETIME  VALID_INCIDENT_RSPNS_TIME_INDC  \
# 0                       16.0                               1
# 1                      127.0                               1
# 2                       19.0                               1
# 3                       44.0                               1
# 4                       46.0                               1
#
#    INCIDENT_CLOSE_DATETIME  HELD_INDICATOR  REOPEN_INDICATOR  \
# 0                   1583.0               0                 0
# 1                  48712.0               0                 0
# 2                   2654.0               0                 0
# 3                    591.0               0                 0
# 4                   5868.0               0                 0
#
#    SPECIAL_EVENT_INDICATOR  ...  CALL_MONTH_NOV  CALL_MONTH_OCT  \
# 0                        0  ...               0               0
# 1                        0  ...               0               0
# 2                        0  ...               0               0
# 3                        0  ...               0               0
# 4                        0  ...               0               0
#
#    CALL_MONTH_SEP  CALL_MONTH  PRCP  SNOW  SNWD  TMAX  TMIN  TAVG_CALC
# 0               0           1  0.00   0.0  12.0  53.0  40.0       46.5
# 1               0           1  0.00   0.0  12.0  53.0  40.0       46.5
# 2               0           1  0.00   0.0  12.0  53.0  40.0       46.5
# 3               0           1  0.00   0.0  12.0  53.0  40.0       46.5
# 4               0           1  0.01   0.0   9.0  52.0  35.0       43.5
#
# [5 rows x 324 columns]

# %% [markdown]
# #### Train test split on both Xs

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=.3)

# %%
X_train1, X_test1, y_train1, y_test1 = train_test_split(X1, y, test_size=.3)

# %% [markdown]
# #### Scale both Xs

# %%
sc = StandardScaler()
X_train_sc = sc.fit_transform(X_train)
X_test_sc = sc.transform(X_test)

# %%
sc1 = StandardScaler()
X_train_sc1 = sc1.fit_transform(X_train1)
X_test_sc1 = sc1.transform(X_test1)

# %% [markdown]
# ### Linear Regression

# %%
linreg = LinearRegression()

linreg.fit(X_train_sc, y_train)

print(f'Training score: {linreg.score(X_train_sc, y_train)}')
print(f'Testing score: {linreg.score(X_test_sc, y_test)}')
# Out:
# Training score: 0.8155436514925168
# Testing score: -1.2719641180298604e+25

# %%
linreg.coef_
# Out:
# array([ 1.26480095e+01,  1.24041366e-01, -3.65555211e+14,  1.92860365e+02,
#         4.18604939e+14,  3.14591142e+02,  3.52846140e+00,  9.02812333e+01,
#         5.61339771e+00,  5.53609736e+14,  8.95416530e+14, -2.10030317e+14,
#         1.01445312e+01,  1.01074219e+00,  6.93750000e+00,  2.75087214e+14,
#        -1.96783457e+14,  4.82573586e+14,  3.32617188e+00, -5.59570312e-01,
#         1.36718750e-01, -1.49591024e+14, -1.36897427e+14,  2.83526325e+14])

# %% [markdown]
# Linear Regression did not do well most likely due to the huge volume of columns in our dataset. We are going to try Lasso and Ridge to regularize and reduce overfitting.

# %% [markdown]
# ### Lasso

# %% [markdown]
# #### Fitting & scoring lasso models on both Xs

# %%
lasso = Lasso()

lasso.fit(X_train_sc, y_train)

print(f'Training: {lasso.score(X_train_sc, y_train)}')
print(f'Testing: {lasso.score(X_test_sc, y_test)}')
# Out:
# Training: 0.8153672724024563
# Testing: 0.8368473327311271

# %%
preds = lasso.predict(X_test_sc)
mse = mean_squared_error(y_test, preds)
np.sqrt(mse)
# Out:
# 225.62225731476641

# %%
lasso1 = Lasso()

lasso1.fit(X_train_sc1, y_train1)

print(f'Training: {lasso1.score(X_train_sc1, y_train1)}')
print(f'Testing: {lasso1.score(X_test_sc1, y_test1)}')
# Out:
# Training: 0.6333629288083515
# Testing: -0.32140595507828484

# %% [markdown]
# Score was better using the first X (no dispatch time) vs the second X (no travel time). Have to decide how to handle travel time as it is highly correlated to response time.

# %% [markdown]
# #### Looking at features the Lasso models kept

# %%
features = X_train.columns

# %%
features1 = X_train1.columns

# %%
lasso_coefs = lasso.coef_

# %%
lasso1_coefs = lasso1.coef_

# %%
coef_df = pd.DataFrame({'features':features, 'coefficients':lasso_coefs})

# %%
coef_df1 = pd.DataFrame({'features':features1, 'coefficients':lasso1_coefs})

# %%
coef_df[coef_df['coefficients'] != 0]
# Out:
#                           features  coefficients
# 0      INITIAL_SEVERITY_LEVEL_CODE      3.472085
# 1        FINAL_SEVERITY_LEVEL_CODE      0.449342
# 3        FIRST_ACTIVATION_DATETIME    193.018453
# 5    INCIDENT_TRAVEL_TM_SECONDS_QY    313.779920
# 6          INCIDENT_CLOSE_DATETIME      2.349293
# ..                             ...           ...
# 312                 CALL_MONTH_MAR      3.093972
# 316                 CALL_MONTH_SEP     -3.338527
# 317                     CALL_MONTH     -0.234961
# 318                           PRCP      2.538173
# 322                           TMIN      0.459597
#
# [63 rows x 2 columns]

# %%
coef_df1[coef_df1['coefficients'] != 0]
# Out:
#                          features  coefficients
# 0     INITIAL_SEVERITY_LEVEL_CODE     35.901861
# 1       FINAL_SEVERITY_LEVEL_CODE      4.469111
# 3    DISPATCH_RESPONSE_SECONDS_QY      5.702355
# 4       FIRST_ACTIVATION_DATETIME    319.166665
# 6         INCIDENT_CLOSE_DATETIME      9.538882
# ..                            ...           ...
# 314                CALL_MONTH_NOV     -0.779306
# 316                CALL_MONTH_SEP      2.454233
# 318                          PRCP      4.373495
# 319                          SNOW      4.841491
# 320                          SNWD      5.007628
#
# [179 rows x 2 columns]

# %%
coef_df.to_csv('data/lasso_coefs.csv')

# %%
coef_df1.to_csv('data/lasso_coefs_no-travel-time.csv')

# %% [markdown]
# ### Ridge

# %% [markdown]
# #### Fitting & scoring ridge models on first X (no dispatch time)

# %%
ridge = Ridge()

ridge.fit(X_train_sc, y_train)

print(f'Training: {ridge.score(X_train_sc, y_train)}')
#         3.66957076e-07,  5.06262123e-08, -2.55653231e-07, -2.40260317e-06,
#         2.20363568e-06, -7.75064765e-07, -5.11405685e-07, -4.12739080e-07,
#        -4.16792904e-07,  0.00000000e+00, -1.80760997e-07, -8.06691291e-07,
#         6.78343660e-07,  5.01926201e-07,  4.09653738e-07,  6.84196337e-07,
#         1.22061029e-06, -1.81212657e-06, -4.20363272e-07,  8.41164131e-08,
#         2.60251623e-07,  1.38756409e-07,  3.93671538e-07, -1.50930099e-08,
#        -3.08975338e-07,  9.95689948e-07, -6.97970002e-07,  7.67272004e-07,
#         6.34545869e-08,  1.34267912e-06,  1.54574609e-06, -3.25504513e-06,
#         1.31501399e-06,  9.84833957e-07, -7.31151212e-07,  2.24993104e-06,
#        -1.91484953e-07, -2.42595013e-06, -8.44461605e-07,  2.57166692e-07,
#        -1.42673859e-06, -4.07588041e-07,  2.79693540e-07,  3.15938329e-08,
#        -7.02668414e-07, -2.36077702e-07,  9.23574366e-07,  5.28762613e-06,
#         7.30984659e-07, -5.83707072e-07,  5.35764562e-07,  1.37869068e-06,
#         0.00000000e+00,  8.00327368e-07, -1.22551007e-06, -1.00878836e-06,
#        -1.80695740e-06, -1.85250683e-06,  6.17722262e-07,  3.27595908e-07,
#         4.67956103e-07,  1.72844670e-07, -1.42884484e-07,  4.17519374e-07,
#         1.22991516e-06,  5.99245751e-07,  1.49368752e-06,  5.65703092e-08,
#        -2.10940411e-07,  7.73862146e-07, -2.23277308e-07,  1.43838883e-06,
#         9.26638674e-08, -3.31088764e-07, -1.35874218e-06, -1.63582475e-07,
#         3.24471153e-07,  7.11343577e-07, -1.03998342e-07, -4.64447626e-07,
#         1.51455467e-07,  1.05668642e-06,  1.33074991e-06, -9.83487869e-07,
#        -7.43877560e-07, -7.17963943e-07, -1.01898099e-06, -1.08755095e-06,
#        -3.33853303e-07, -1.56970579e-06, -2.22800811e-06, -9.50926643e-07,
#        -3.46329401e-07, -6.41624383e-07, -1.22722917e-07, -5.39057921e-07,
#        -1.02854506e-06,  2.19524326e-07,  2.01179309e-12, -3.94486078e-12,
#         1.22599949e-05, -1.58485909e-05, -8.53796004e-06, -9.71719134e-06,
#         1.44672179e-05,  1.09605885e-05, -6.09664079e-06,  5.18396823e-06,
#        -9.44366707e-06, -1.20896270e-06,  7.14421602e-06,  7.44390544e-06,
#        -6.30805686e-07,  9.50255884e-07, -5.10777855e-07, -5.43566990e-07,
#         4.99999926e-01,  4.99999320e-01])

# %% [markdown]
# We got decent scores for Lasso and Ridge (~82% for train, ~84% for test). Next we're going to try hyperparamater tuning.

# %%
l_alphas = np.logspace(-3, 0, 100)

lasso_cv = LassoCV(alphas=[0.01, 0.1, 1], max_iter=10000, cv=5)

lasso_cv.fit(X_train_sc1, y_train1)

print(f'Training: {lasso_cv.score(X_train_sc1, y_train1)}')
print(f'Testing: {lasso_cv.score(X_test_sc1, y_test1)}')
# Out:
# /Users/ashleypoon/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 7989515.3052277565, tolerance: 254401.9280286428
#   model = cd_fast.enet_coordinate_descent_gram(
# /Users/ashleypoon/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_coordinate_descent.py:525: ConvergenceWarning: Objective did not converge. You might want to increase the number of iterations. Duality gap: 12627958.333904982, tolerance: 271275.131001391
#   model = cd_fast.enet_coordinate_descent_gram(
# Training: 0.6333629288083515
# Testing: -0.32140595507828484
