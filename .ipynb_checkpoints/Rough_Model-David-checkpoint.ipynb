# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plot
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LinearRegression, Lasso, Ridge
from sklearn.preprocessing import StandardScaler

# imports modeling
from sklearn.linear_model import LogisticRegression, LinearRegression
from sklearn.pipeline import make_pipeline, Pipeline
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import LinearSVC, SVC
from sklearn.ensemble import RandomForestClassifier, AdaBoostClassifier, BaggingClassifier
from sklearn.tree import DecisionTreeClassifier

# sklearn metrics
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay, accuracy_score

# %%
# load data 
df = pd.read_csv('data/ems_weather.csv')
features = df.columns

# definitely drop these:
drop_features1 = ['Unnamed: 0',
                 'INCIDENT_RESPONSE_SECONDS_QY', 
                 'CAD_INCIDENT_ID', 
                 'FIRST_ASSIGNMENT_DATETIME', 
                 'INCIDENT_TRAVEL_TM_SECONDS_QY',
                 'DISPATCH_RESPONSE_SECONDS_QY',]
# suggest dropping these: 
drop_features1 += list(features[230:594]) # zip codes
drop_features1 += list(features[670:831]) # city council district, community district, community school dist, congressional district
drop_features1 += ['AWND']

# X, y TTS
X = df.drop(columns=drop_features)
y = df['INCIDENT_RESPONSE_SECONDS_QY']
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state = 42)

# scale
ss = StandardScaler()
Z_train = ss.fit_transform(X_train)  
Z_test = ss.transform(X_test)

# %%
# instaniate all models
logreg = LogisticRegression()
svc = SVC()
forest = RandomForestClassifier()
abc = AdaBoostClassifier()
bag = BaggingClassifier()

# create list of models
models = [logreg, svc, forest, abc, bag]

# %%
def modeling(X_train, X_test, y_train, y_test, models):
    
    # create lists for scores 
    train_score = []
    test_score = []
    acc_score = []
    
    # fit and score each model
    for model in models:
        # fit
        model.fit(X_train, y_train)
        # score
        train_score.append(cross_val_score(model, X_train, y_train).mean())
        test_score.append(cross_val_score(model, X_test, y_test).mean())
        
    # generate dataframe
    return pd.DataFrame(data=[train_score, test_score],
                 index=['Training Data', 'Test Data'],
                 columns=[str(c) for c in models]).T

# %%
model_scores = modeling(Z_train, Z_test, y_train, y_test, models)
model_scores
# Out:
# /Users/trivium/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# /Users/trivium/opt/anaconda3/lib/python3.8/site-packages/sklearn/model_selection/_split.py:670: UserWarning: The least populated class in y has only 1 members, which is less than n_splits=5.
#   warnings.warn(("The least populated class in y has only %d"
# /Users/trivium/opt/anaconda3/lib/python3.8/site-packages/sklearn/linear_model/_logistic.py:762: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...
